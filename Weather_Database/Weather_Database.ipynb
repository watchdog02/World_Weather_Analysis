# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key
from datetime import datetime
from citipy import citipy

# %%
lats= np.random.uniform(low= -90, high= 90, size= 2000)
lngs= np.random.uniform(low= -90, high= 90, size= 2000)
lat_lngs = zip(lats,lngs)
# Add the latitudes to a list
coordinates= list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Starting URL for Weather Map API Call
url= "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data
city_data=[]
# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in our list
for i in range(len(cities)):
    # Group citites in sets of 50 for loggin purposes
    if (i % 50 == 0 and i >= 50):
        set_count +=1
        record_count = 1
    # Create endpoint URL with each city
    city_url= url + "&q=" + cities[i]
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for loggin purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1 
    # Create endpoint URL with each city
    city_url= url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather= requests.get(city_url).json()
        # Parse out the needed data
        city_lat= city_weather['coord']['lat']
        city_lng= city_weather['coord']['lon']
        city_max_temp= city_weather['main']['temp_max']
        city_humidity= city_weather['main']['humidity']
        city_clouds= city_weather['clouds']['all']
        city_wind= city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description= city_weather['weather'][0]['description']
        # Convert the date to ISO standard
        city_date= datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list
        city_data.append({"City": city.title(),"Country": city_country, "Lat": city_lat,
                         "Lng": city_lng, "Max Temp": city_max_temp,
                         "Humidity": city_humidity, "Cloudiness": city_clouds,
                         "Wind Speed": city_wind, "Current Description": city_description})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
    pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | east london
# Processing Record 2 of Set 16 | busselton
# Processing Record 3 of Set 16 | ushuaia
# Processing Record 4 of Set 16 | punta arenas
# Processing Record 5 of Set 16 | sergeyevka
# Processing Record 6 of Set 16 | clyde river
# Processing Record 7 of Set 16 | ilulissat
# Processing Record 8 of Set 16 | bharatpur
# Processing Record 9 of Set 16 | hermanus
# Processing Record 10 of Set 16 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 16 | bredasdorp
# Processing Record 12 of Set 16 | inhambane
# Processing Record 13 of Set 16 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 16 | hambantota
# Processing Record 15 of Set 16 | saint george
# Processing Record 16 of Set 16 | aasiaat
# Processing Record 17 of Set 16 | jaslo
# Processing Record 18 of Set 16 | saint-philippe
# Processing Record 19 of Set 16 | paita
# Processing Record 20 of Set 16 | margate
# Processing Record 21 of Set 16 | vuktyl
# Processing Record 22 of Set 16 | arraial do cabo
# Processing Record 23 of Set 16 | dikson
# Processing Record 24 of Set 16 | port alfred
# Processing Record 25 of Set 16 | sistranda
# Processing Record 26 of Set 16 | cape town
# Processing Record 27 of Set 16 | dakar
# Processing Record 28 of Set 16 | sao francisco
# Processing Record 29 of Set 16 | skibotn
# Processing Record 30 of Set 16 | horodyshche
# Processing Record 31 of Set 16 | jamestown
# Processing Record 32 of Set 16 | santo domingo
# Processing Record 33 of Set 16 | santa cruz
# Processing Record 34 of Set 16 | gulshat
# City not found. Skipping...
# Processing Record 35 of Set 16 | caravelas
# Processing Record 36 of Set 16 | laguna
# Processing Record 37 of Set 16 | saint anthony
# Processing Record 38 of Set 16 | lagoa
# Processing Record 39 of Set 16 | alenquer
# Processing Record 40 of Set 16 | zaysan
# Processing Record 41 of Set 16 | ostrovnoy
# Processing Record 42 of Set 16 | maniitsoq
# Processing Record 43 of Set 16 | taki
# Processing Record 44 of Set 16 | souillac
# Processing Record 45 of Set 16 | mhlambanyatsi
# Processing Record 46 of Set 16 | trinidad
# Processing Record 47 of Set 16 | longyearbyen
# Processing Record 48 of Set 16 | saint-michel-des-saints
# Processing Record 49 of Set 16 | ravar
# Processing Record 50 of Set 16 | kelo
# Processing Record 1 of Set 17 | moose factory
# Processing Record 2 of Set 17 | scottsburgh
# City not found. Skipping...
# Processing Record 3 of Set 17 | pangnirtung
# Processing Record 4 of Set 17 | victoria
# Processing Record 5 of Set 17 | gobabis
# Processing Record 6 of Set 17 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 17 | namibe
# Processing Record 8 of Set 17 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 17 | sinnamary
# Processing Record 10 of Set 17 | llanes
# Processing Record 11 of Set 17 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 17 | puerto ayacucho
# Processing Record 13 of Set 17 | copiapo
# Processing Record 14 of Set 17 | touros
# Processing Record 15 of Set 17 | qaanaaq
# Processing Record 16 of Set 17 | torbay
# Processing Record 17 of Set 17 | maragogi
# Processing Record 18 of Set 17 | mahebourg
# Processing Record 19 of Set 17 | alakurtti
# Processing Record 20 of Set 17 | upernavik
# Processing Record 21 of Set 17 | pangody
# Processing Record 22 of Set 17 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 17 | rudnichnyy
# Processing Record 24 of Set 17 | traverse city
# Processing Record 25 of Set 17 | darab
# Processing Record 26 of Set 17 | ust-charyshskaya pristan
# Processing Record 27 of Set 17 | sioux lookout
# Processing Record 28 of Set 17 | devrek
# Processing Record 29 of Set 17 | bondoukou
# Processing Record 30 of Set 17 | agnibilekrou
# Processing Record 31 of Set 17 | chuy
# Processing Record 32 of Set 17 | bambous virieux
# Processing Record 33 of Set 17 | talnakh
# Processing Record 34 of Set 17 | lima
# Processing Record 35 of Set 17 | toamasina
# Processing Record 36 of Set 17 | cidreira
# Processing Record 37 of Set 17 | luanda
# Processing Record 38 of Set 17 | tevriz
# Processing Record 39 of Set 17 | snasa
# Processing Record 40 of Set 17 | salalah
# Processing Record 41 of Set 17 | georgetown
# Processing Record 42 of Set 17 | sambava
# Processing Record 43 of Set 17 | shchelyayur
# City not found. Skipping...
# Processing Record 44 of Set 17 | road town
# Processing Record 45 of Set 17 | ponta do sol
# Processing Record 46 of Set 17 | grindavik
# Processing Record 47 of Set 17 | iranshahr
# Processing Record 48 of Set 17 | meulaboh
# Processing Record 49 of Set 17 | arnedo
# Processing Record 50 of Set 17 | tazmalt
# Processing Record 1 of Set 18 | filingue
# Processing Record 2 of Set 18 | acara
# Processing Record 3 of Set 18 | sundby
# Processing Record 4 of Set 18 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 18 | gwanda
# Processing Record 6 of Set 18 | shakawe
# Processing Record 7 of Set 18 | correntina
# Processing Record 8 of Set 18 | artyom
# Processing Record 9 of Set 18 | ribeira grande
# Processing Record 10 of Set 18 | mar del plata
# Processing Record 11 of Set 18 | mitu
# Processing Record 12 of Set 18 | adrar
# Processing Record 13 of Set 18 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 18 | bouna
# Processing Record 15 of Set 18 | solovetskiy
# City not found. Skipping...
# Processing Record 16 of Set 18 | sakakah
# Processing Record 17 of Set 18 | klaksvik
# Processing Record 18 of Set 18 | mehamn
# Processing Record 19 of Set 18 | saldanha
# Processing Record 20 of Set 18 | villa maria
# Processing Record 21 of Set 18 | saint-pierre
# Processing Record 22 of Set 18 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 18 | awjilah
# Processing Record 24 of Set 18 | kazalinsk
# City not found. Skipping...
# Processing Record 25 of Set 18 | goderich
# Processing Record 26 of Set 18 | mitsamiouli
# Processing Record 27 of Set 18 | coihaique
# Processing Record 28 of Set 18 | deogarh
# Processing Record 29 of Set 18 | saint-augustin
# Processing Record 30 of Set 18 | molchanovo
# Processing Record 31 of Set 18 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 18 | lichinga
# Processing Record 33 of Set 18 | luderitz
# Processing Record 34 of Set 18 | kedrovyy
# Processing Record 35 of Set 18 | petukhovo
# Processing Record 36 of Set 18 | husavik
# Processing Record 37 of Set 18 | pioner
# Processing Record 38 of Set 18 | odemis
# City not found. Skipping...
# Processing Record 39 of Set 18 | santa isabel do rio negro
# Processing Record 40 of Set 18 | kalmunai
# Processing Record 41 of Set 18 | sao joao da barra
# Processing Record 42 of Set 18 | vardo
# Processing Record 43 of Set 18 | kyabe
# Processing Record 44 of Set 18 | mocambique
# City not found. Skipping...
# Processing Record 45 of Set 18 | paracatu
# Processing Record 46 of Set 18 | arlit
# Processing Record 47 of Set 18 | narsaq
# Processing Record 48 of Set 18 | kibala
# Processing Record 49 of Set 18 | iqaluit
# Processing Record 50 of Set 18 | harsin
# Processing Record 1 of Set 19 | ugoofaaru
# Processing Record 2 of Set 19 | calama
# Processing Record 3 of Set 19 | guhagar
# Processing Record 4 of Set 19 | umm lajj
# Processing Record 5 of Set 19 | ati
# Processing Record 6 of Set 19 | hamilton
# Processing Record 7 of Set 19 | salinopolis
# Processing Record 8 of Set 19 | muros
# Processing Record 9 of Set 19 | misratah
# Processing Record 10 of Set 19 | semey
# Processing Record 11 of Set 19 | tasiilaq
# Processing Record 12 of Set 19 | sorland
# Processing Record 13 of Set 19 | le port
# Processing Record 14 of Set 19 | methana
# Processing Record 15 of Set 19 | doka
# Processing Record 16 of Set 19 | lixourion
# Processing Record 17 of Set 19 | aksu
# Processing Record 18 of Set 19 | carnarvon
# Processing Record 19 of Set 19 | calarasi
# Processing Record 20 of Set 19 | hithadhoo
# Processing Record 21 of Set 19 | kingston
# Processing Record 22 of Set 19 | boca do acre
# Processing Record 23 of Set 19 | liverpool
# Processing Record 24 of Set 19 | camana
# Processing Record 25 of Set 19 | chimbote
# Processing Record 26 of Set 19 | alta floresta
# Processing Record 27 of Set 19 | kalmar
# Processing Record 28 of Set 19 | nikel
# Processing Record 29 of Set 19 | los llanos de aridane
# Processing Record 30 of Set 19 | nouadhibou
# Processing Record 31 of Set 19 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 19 | lebu
# Processing Record 33 of Set 19 | fillan
# Processing Record 34 of Set 19 | port elizabeth
# Processing Record 35 of Set 19 | gaoua
# Processing Record 36 of Set 19 | honningsvag
# Processing Record 37 of Set 19 | san martin
# Processing Record 38 of Set 19 | beloha
# Processing Record 39 of Set 19 | beyneu
# Processing Record 40 of Set 19 | yushala
# Processing Record 41 of Set 19 | casablanca
# Processing Record 42 of Set 19 | kruisfontein
# Processing Record 43 of Set 19 | matagami
# Processing Record 44 of Set 19 | sabibah
# City not found. Skipping...
# Processing Record 45 of Set 19 | arica
# Processing Record 46 of Set 19 | manoel urbano
# Processing Record 47 of Set 19 | byumba
# Processing Record 48 of Set 19 | scarsdale
# Processing Record 49 of Set 19 | teguldet
# Processing Record 50 of Set 19 | komsomolskiy
# Processing Record 1 of Set 20 | taybad
# Processing Record 2 of Set 20 | vila velha
# Processing Record 3 of Set 20 | leh
# Processing Record 4 of Set 20 | corrente
# Processing Record 5 of Set 20 | guipavas
# Processing Record 6 of Set 20 | mezen
# Processing Record 7 of Set 20 | lakhtar
# Processing Record 8 of Set 20 | belmonte
# Processing Record 9 of Set 20 | lozovo
# Processing Record 10 of Set 20 | saint austell
# Processing Record 11 of Set 20 | barrinha
# Processing Record 12 of Set 20 | cape coast
# Processing Record 13 of Set 20 | deder
# Processing Record 14 of Set 20 | mahon
# Processing Record 15 of Set 20 | rovaniemi
# Processing Record 16 of Set 20 | beitbridge
# Processing Record 17 of Set 20 | ilhabela
# Processing Record 18 of Set 20 | pisco
# Processing Record 19 of Set 20 | port blair
# Processing Record 20 of Set 20 | nanortalik
# Processing Record 21 of Set 20 | chapais
# Processing Record 22 of Set 20 | amboasary
# Processing Record 23 of Set 20 | takoradi
# Processing Record 24 of Set 20 | karatau
# Processing Record 25 of Set 20 | masyaf
# Processing Record 26 of Set 20 | wadi maliz
# Processing Record 27 of Set 20 | luangwa
# Processing Record 28 of Set 20 | rodrigues alves
# Processing Record 29 of Set 20 | aguas de lindoia
# Processing Record 30 of Set 20 | turgenevo
# Processing Record 31 of Set 20 | molteno
# Processing Record 32 of Set 20 | yenisehir
# Processing Record 33 of Set 20 | salvador
# Processing Record 34 of Set 20 | plouzane
# Processing Record 35 of Set 20 | dingle
# Processing Record 36 of Set 20 | ambodifototra
# City not found. Skipping...
# Processing Record 37 of Set 20 | ponta delgada
# Processing Record 38 of Set 20 | paamiut
# Processing Record 39 of Set 20 | keene
# Processing Record 40 of Set 20 | constantine
# Processing Record 41 of Set 20 | atraulia
# Processing Record 42 of Set 20 | gunib
# Processing Record 43 of Set 20 | port-cartier
# Processing Record 44 of Set 20 | taltal
# Processing Record 45 of Set 20 | tokonou
# Processing Record 46 of Set 20 | gualaquiza
# Processing Record 47 of Set 20 | mut
# Processing Record 48 of Set 20 | catamarca
# Processing Record 49 of Set 20 | miranda
# Processing Record 50 of Set 20 | gangotri
# City not found. Skipping...
# Processing Record 1 of Set 21 | aranos
# Processing Record 2 of Set 21 | gumdag
# Processing Record 3 of Set 21 | campoverde
# Processing Record 4 of Set 21 | bam
# Processing Record 5 of Set 21 | skjervoy
# Processing Record 6 of Set 21 | petauke
# Processing Record 7 of Set 21 | bubaque
# Processing Record 8 of Set 21 | san pedro
# Processing Record 9 of Set 21 | acarau
# Processing Record 10 of Set 21 | urubicha
# Processing Record 11 of Set 21 | luba
# Processing Record 12 of Set 21 | tessalit
# Processing Record 13 of Set 21 | gondar
# Processing Record 14 of Set 21 | derzhavinsk
# Processing Record 15 of Set 21 | cayenne
# Processing Record 16 of Set 21 | kem
# Processing Record 17 of Set 21 | malyn
# Processing Record 18 of Set 21 | skrunda
# Processing Record 19 of Set 21 | sur
# Processing Record 20 of Set 21 | farafangana
# Processing Record 21 of Set 21 | hualmay
# Processing Record 22 of Set 21 | manono
# Processing Record 23 of Set 21 | moca
# Processing Record 24 of Set 21 | chabahar
# Processing Record 25 of Set 21 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 21 | narok
# Processing Record 27 of Set 21 | panama city
# Processing Record 28 of Set 21 | kindu
# Processing Record 29 of Set 21 | andenes
# Processing Record 30 of Set 21 | ostersund
# Processing Record 31 of Set 21 | kormilovka
# Processing Record 32 of Set 21 | hobyo
# Processing Record 33 of Set 21 | turukhansk
# Processing Record 34 of Set 21 | njombe
# Processing Record 35 of Set 21 | rena
# Processing Record 36 of Set 21 | pacasmayo
# Processing Record 37 of Set 21 | henties bay
# Processing Record 38 of Set 21 | umm kaddadah
# Processing Record 39 of Set 21 | aizpute
# Processing Record 40 of Set 21 | manaure
# Processing Record 41 of Set 21 | tetiyiv
# Processing Record 42 of Set 21 | ust-kan
# Processing Record 43 of Set 21 | cirpan
# City not found. Skipping...
# Processing Record 44 of Set 21 | sawakin
# Processing Record 45 of Set 21 | mihona
# Processing Record 46 of Set 21 | penzance
# Processing Record 47 of Set 21 | villarrica
# Processing Record 48 of Set 21 | lincoln
# Processing Record 49 of Set 21 | rincon
# Processing Record 50 of Set 21 | ilebo
# Processing Record 1 of Set 22 | bridlington
# Processing Record 2 of Set 22 | valparaiso
# Processing Record 3 of Set 22 | formosa
# Processing Record 4 of Set 22 | marzuq
# Processing Record 5 of Set 22 | trairi
# Processing Record 6 of Set 22 | beira
# Processing Record 7 of Set 22 | codrington
# Processing Record 8 of Set 22 | rio verde de mato grosso
# Processing Record 9 of Set 22 | fuerte olimpo
# Processing Record 10 of Set 22 | praia
# Processing Record 11 of Set 22 | tiznit
# Processing Record 12 of Set 22 | taoudenni
# Processing Record 13 of Set 22 | porto novo
# Processing Record 14 of Set 22 | sembabule
# Processing Record 15 of Set 22 | belogradcik
# City not found. Skipping...
# Processing Record 16 of Set 22 | faya
# Processing Record 17 of Set 22 | keflavik
# Processing Record 18 of Set 22 | kati
# Processing Record 19 of Set 22 | wheatley
# Processing Record 20 of Set 22 | capitao poco
# Processing Record 21 of Set 22 | axim
# Processing Record 22 of Set 22 | san juan
# Processing Record 23 of Set 22 | torquay
# Processing Record 24 of Set 22 | itaituba
# Processing Record 25 of Set 22 | korla
# Processing Record 26 of Set 22 | gunjur
# Processing Record 27 of Set 22 | bengkulu
# Processing Record 28 of Set 22 | banbury
# Processing Record 29 of Set 22 | asosa
# Processing Record 30 of Set 22 | roald
# Processing Record 31 of Set 22 | borlange
# City not found. Skipping...
# Processing Record 32 of Set 22 | vagur
# Processing Record 33 of Set 22 | monrovia
# Processing Record 34 of Set 22 | letka
# Processing Record 35 of Set 22 | altay
# Processing Record 36 of Set 22 | harlingen
# Processing Record 37 of Set 22 | kolaras
# Processing Record 38 of Set 22 | safaga
# Processing Record 39 of Set 22 | luau
# Processing Record 40 of Set 22 | skelleftea
# Processing Record 41 of Set 22 | inirida
# Processing Record 42 of Set 22 | maraa
# Processing Record 43 of Set 22 | jensen beach
# Processing Record 44 of Set 22 | viedma
# Processing Record 45 of Set 22 | padang
# Processing Record 46 of Set 22 | argalasti
# Processing Record 47 of Set 22 | abu dhabi
# Processing Record 48 of Set 22 | itea
# Processing Record 49 of Set 22 | port-gentil
# Processing Record 50 of Set 22 | slevik
# City not found. Skipping...
# Processing Record 1 of Set 23 | shetpe
# Processing Record 2 of Set 23 | chadiza
# Processing Record 3 of Set 23 | comodoro rivadavia
# Processing Record 4 of Set 23 | andover
# Processing Record 5 of Set 23 | yar-sale
# Processing Record 6 of Set 23 | tsabong
# Processing Record 7 of Set 23 | urucui
# Processing Record 8 of Set 23 | pinar del rio
# Processing Record 9 of Set 23 | kuusamo
# Processing Record 10 of Set 23 | bassar
# Processing Record 11 of Set 23 | venezuela
# Processing Record 12 of Set 23 | kargasok
# Processing Record 13 of Set 23 | deh rawud
# City not found. Skipping...
# Processing Record 14 of Set 23 | gamba
# Processing Record 15 of Set 23 | mayumba
# Processing Record 16 of Set 23 | nuuk
# Processing Record 17 of Set 23 | pionerskiy
# Processing Record 18 of Set 23 | sfantu gheorghe
# Processing Record 19 of Set 23 | santa maria
# Processing Record 20 of Set 23 | toliary
# City not found. Skipping...
# Processing Record 21 of Set 23 | aurillac
# Processing Record 22 of Set 23 | naryan-mar
# Processing Record 23 of Set 23 | arandis
# Processing Record 24 of Set 23 | konigs wusterhausen
# Processing Record 25 of Set 23 | zarand
# Processing Record 26 of Set 23 | goose creek
# Processing Record 27 of Set 23 | omboue
# Processing Record 28 of Set 23 | abha
# Processing Record 29 of Set 23 | saeby
# Processing Record 30 of Set 23 | harper
# Processing Record 31 of Set 23 | barbar
# City not found. Skipping...
# Processing Record 32 of Set 23 | espanola
# Processing Record 33 of Set 23 | tukrah
# Processing Record 34 of Set 23 | buchanan
# Processing Record 35 of Set 23 | rundu
# Processing Record 36 of Set 23 | vila franca do campo
# Processing Record 37 of Set 23 | cozumel
# Processing Record 38 of Set 23 | havoysund
# Processing Record 39 of Set 23 | riachao
# Processing Record 40 of Set 23 | umm durman
# City not found. Skipping...
# Processing Record 41 of Set 23 | kargat
# Processing Record 42 of Set 23 | vestmannaeyjar
# Processing Record 43 of Set 23 | anar darreh
# City not found. Skipping...
# Processing Record 44 of Set 23 | duz
# City not found. Skipping...
# Processing Record 45 of Set 23 | garissa
# Processing Record 46 of Set 23 | koulikoro
# Processing Record 47 of Set 23 | matara
# Processing Record 48 of Set 23 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 23 | formoso do araguaia
# City not found. Skipping...
# Processing Record 50 of Set 23 | mattru
# Processing Record 1 of Set 24 | richards bay
# Processing Record 2 of Set 24 | bandarbeyla
# Processing Record 3 of Set 24 | kattivakkam
# Processing Record 4 of Set 24 | fez
# Processing Record 5 of Set 24 | abu samrah
# Processing Record 6 of Set 24 | beinamar
# Processing Record 7 of Set 24 | deori
# Processing Record 8 of Set 24 | qaqortoq
# Processing Record 9 of Set 24 | sinjar
# Processing Record 10 of Set 24 | guisa
# Processing Record 11 of Set 24 | bria
# Processing Record 12 of Set 24 | oranjemund
# Processing Record 13 of Set 24 | veraval
# Processing Record 14 of Set 24 | silopi
# Processing Record 15 of Set 24 | pakala
# Processing Record 16 of Set 24 | puerto baquerizo moreno
# Processing Record 17 of Set 24 | nizhnevartovsk
# Processing Record 18 of Set 24 | srivardhan
# Processing Record 19 of Set 24 | umm ruwabah
# City not found. Skipping...
# Processing Record 20 of Set 24 | yemtsa
# Processing Record 21 of Set 24 | antofagasta
# Processing Record 22 of Set 24 | aden
# Processing Record 23 of Set 24 | kangaatsiaq
# Processing Record 24 of Set 24 | moundou
# Processing Record 25 of Set 24 | neuquen
# Processing Record 26 of Set 24 | porto nacional
# Processing Record 27 of Set 24 | tazovskiy
# Processing Record 28 of Set 24 | atar
# Processing Record 29 of Set 24 | aksarka
# Processing Record 30 of Set 24 | narbonne
# Processing Record 31 of Set 24 | sao miguel do araguaia
# Processing Record 32 of Set 24 | yarim
# Processing Record 33 of Set 24 | thinadhoo
# Processing Record 34 of Set 24 | portobelo
# Processing Record 35 of Set 24 | tsiroanomandidy
# Processing Record 36 of Set 24 | abapo
# Processing Record 37 of Set 24 | mazagao
# Processing Record 38 of Set 24 | nalut
# Processing Record 39 of Set 24 | zlitan
# Processing Record 40 of Set 24 | tucuma
# Processing Record 41 of Set 24 | kaoma
# Processing Record 42 of Set 24 | golden gate
# Processing Record 43 of Set 24 | mwinilunga
# Processing Record 44 of Set 24 | oksfjord
# Processing Record 45 of Set 24 | uribia
# Processing Record 46 of Set 24 | oneonta
# Processing Record 47 of Set 24 | louis trichardt
# Processing Record 48 of Set 24 | nicoya
# Processing Record 49 of Set 24 | chibombo
# Processing Record 50 of Set 24 | darnah
# Processing Record 1 of Set 25 | pipri
# Processing Record 2 of Set 25 | gandajika
# Processing Record 3 of Set 25 | leshukonskoye
# Processing Record 4 of Set 25 | lucapa
# Processing Record 5 of Set 25 | mayahi
# Processing Record 6 of Set 25 | monroe
# Processing Record 7 of Set 25 | staryy nadym
# Processing Record 8 of Set 25 | yeletskiy
# City not found. Skipping...
# Processing Record 9 of Set 25 | sanquhar
# Processing Record 10 of Set 25 | araouane
# Processing Record 11 of Set 25 | laguna de perlas
# Processing Record 12 of Set 25 | mecca
# Processing Record 13 of Set 25 | saint-jean-de-braye
# Processing Record 14 of Set 25 | castro
# Processing Record 15 of Set 25 | babana
# Processing Record 16 of Set 25 | rio brilhante
# Processing Record 17 of Set 25 | kavaratti
# Processing Record 18 of Set 25 | watsa
# Processing Record 19 of Set 25 | tsogni
# Processing Record 20 of Set 25 | kalabo
# Processing Record 21 of Set 25 | malangali
# Processing Record 22 of Set 25 | eyl
# Processing Record 23 of Set 25 | kortemark
# Processing Record 24 of Set 25 | fray bentos
# Processing Record 25 of Set 25 | kunzelsau
# Processing Record 26 of Set 25 | clarence town
# Processing Record 27 of Set 25 | mandal
# Processing Record 28 of Set 25 | nurota
# Processing Record 29 of Set 25 | mpongwe
# Processing Record 30 of Set 25 | bodmin
# Processing Record 31 of Set 25 | tambacounda
# Processing Record 32 of Set 25 | pulaski
# Processing Record 33 of Set 25 | manaus
# Processing Record 34 of Set 25 | gwadar
# Processing Record 35 of Set 25 | damienesti
# Processing Record 36 of Set 25 | barawe
# City not found. Skipping...
# Processing Record 37 of Set 25 | galle
# Processing Record 38 of Set 25 | bozova
# Processing Record 39 of Set 25 | rawson
# Processing Record 40 of Set 25 | albany
# Processing Record 41 of Set 25 | morondava
# Processing Record 42 of Set 25 | marmaris
# Processing Record 43 of Set 25 | najran
# Processing Record 44 of Set 25 | vilcun
# Processing Record 45 of Set 25 | chardara
# Processing Record 46 of Set 25 | tolland
# Processing Record 47 of Set 25 | pallasovka
# Processing Record 48 of Set 25 | bud
# Processing Record 49 of Set 25 | iralaya
# Processing Record 50 of Set 25 | pappados
# Processing Record 1 of Set 26 | westport
# Processing Record 2 of Set 26 | karasjok
# Processing Record 3 of Set 26 | eyrarbakki
# Processing Record 4 of Set 26 | booue
# Processing Record 5 of Set 26 | vorontsovka
# Processing Record 6 of Set 26 | bathsheba
# Processing Record 7 of Set 26 | igrim
# Processing Record 8 of Set 26 | araci
# Processing Record 9 of Set 26 | san gavino monreale
# Processing Record 10 of Set 26 | coquimbo
# Processing Record 11 of Set 26 | kamskiye polyany
# Processing Record 12 of Set 26 | kongolo
# Processing Record 13 of Set 26 | hargeysa
# Processing Record 14 of Set 26 | mindelo
# Processing Record 15 of Set 26 | chuka
# Processing Record 16 of Set 26 | bonthe
# Processing Record 17 of Set 26 | ushtobe
# Processing Record 18 of Set 26 | manturovo
# Processing Record 19 of Set 26 | buqayq
# City not found. Skipping...
# Processing Record 20 of Set 26 | baiculesti
# Processing Record 21 of Set 26 | windhoek
# Processing Record 22 of Set 26 | cabinda
# Processing Record 23 of Set 26 | shu
# Processing Record 24 of Set 26 | rocha
# Processing Record 25 of Set 26 | itarare
# Processing Record 26 of Set 26 | san ignacio
# Processing Record 27 of Set 26 | quatre cocos
# Processing Record 28 of Set 26 | nantucket
# Processing Record 29 of Set 26 | la ligua
# Processing Record 30 of Set 26 | malinovoye ozero
# Processing Record 31 of Set 26 | las tunas
# Processing Record 32 of Set 26 | bath
# Processing Record 33 of Set 26 | paharpur
# Processing Record 34 of Set 26 | kutum
# Processing Record 35 of Set 26 | sumbe
# Processing Record 36 of Set 26 | busembatia
# Processing Record 37 of Set 26 | sao filipe
# Processing Record 38 of Set 26 | sovetskiy
# Processing Record 39 of Set 26 | unnao
# Processing Record 40 of Set 26 | suoyarvi
# Processing Record 41 of Set 26 | kuvandyk
# Processing Record 42 of Set 26 | puerto ayora
# Processing Record 43 of Set 26 | toktogul
# Processing Record 44 of Set 26 | suleja
# Processing Record 45 of Set 26 | isabela
# Processing Record 46 of Set 26 | berlevag
# Processing Record 47 of Set 26 | gravdal
# Processing Record 48 of Set 26 | durgapur
# Processing Record 49 of Set 26 | sarmellek
# Processing Record 50 of Set 26 | santa cecilia
# Processing Record 1 of Set 27 | burgersdorp
# Processing Record 2 of Set 27 | calabar
# Processing Record 3 of Set 27 | aswan
# Processing Record 4 of Set 27 | karaul
# City not found. Skipping...
# Processing Record 5 of Set 27 | kifri
# Processing Record 6 of Set 27 | cruzeiro do sul
# Processing Record 7 of Set 27 | krasnoselkup
# Processing Record 8 of Set 27 | sirumugai
# Processing Record 9 of Set 27 | cumra
# Processing Record 10 of Set 27 | mangrol
# Processing Record 11 of Set 27 | lerik
# Processing Record 12 of Set 27 | kayerkan
# Processing Record 13 of Set 27 | turkeve
# Processing Record 14 of Set 27 | kapoeta
# Processing Record 15 of Set 27 | marquette
# Processing Record 16 of Set 27 | sault sainte marie
# Processing Record 17 of Set 27 | wagar
# Processing Record 18 of Set 27 | ancud
# Processing Record 19 of Set 27 | salta
# Processing Record 20 of Set 27 | utinga
# Processing Record 21 of Set 27 | alizai
# Processing Record 22 of Set 27 | nara
# Processing Record 23 of Set 27 | igarka
# Processing Record 24 of Set 27 | xuddur
# Processing Record 25 of Set 27 | karaton
# Processing Record 26 of Set 27 | chermoz
# Processing Record 27 of Set 27 | litoral del san juan
# City not found. Skipping...
# Processing Record 28 of Set 27 | glen allen
# Processing Record 29 of Set 27 | alekseyevka
# Processing Record 30 of Set 27 | stykkisholmur
# Processing Record 31 of Set 27 | autun
# Processing Record 32 of Set 27 | bahia blanca
# Processing Record 33 of Set 27 | liwale
# Processing Record 34 of Set 27 | qasigiannguit
# Processing Record 35 of Set 27 | celendin
# Processing Record 36 of Set 27 | tres arroyos
# Processing Record 37 of Set 27 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 27 | nadym
# Processing Record 39 of Set 27 | robertsport
# Processing Record 40 of Set 27 | pimentel
# Processing Record 41 of Set 27 | qarqin
# Processing Record 42 of Set 27 | laurens
# Processing Record 43 of Set 27 | caiaponia
# Processing Record 44 of Set 27 | puerto quijarro
# Processing Record 45 of Set 27 | norilsk
# Processing Record 46 of Set 27 | ipanema
# Processing Record 47 of Set 27 | balkhash
# Processing Record 48 of Set 27 | scarborough
# Processing Record 49 of Set 27 | khandbari
# Processing Record 50 of Set 27 | marsh harbour
# Processing Record 1 of Set 28 | waddan
# Processing Record 2 of Set 28 | horqueta
# Processing Record 3 of Set 28 | bayburt
# Processing Record 4 of Set 28 | velikie luki
# City not found. Skipping...
# Processing Record 5 of Set 28 | marawi
# Processing Record 6 of Set 28 | ljungby
# Processing Record 7 of Set 28 | camopi
# Processing Record 8 of Set 28 | makokou
# Processing Record 9 of Set 28 | urengoy
# Processing Record 10 of Set 28 | pustoshka
# Processing Record 11 of Set 28 | punta de bombon
# Processing Record 12 of Set 28 | shawville
# Processing Record 13 of Set 28 | svetlyy
# Processing Record 14 of Set 28 | bonfim
# Processing Record 15 of Set 28 | san cristobal
# Processing Record 16 of Set 28 | fort myers beach
# Processing Record 17 of Set 28 | antsla
# Processing Record 18 of Set 28 | rozkishne
# Processing Record 19 of Set 28 | rajshahi
# Processing Record 20 of Set 28 | sargatskoye
# Processing Record 21 of Set 28 | usvyaty
# Processing Record 22 of Set 28 | rojhan
# Processing Record 23 of Set 28 | shelburne
# Processing Record 24 of Set 28 | umea
# Processing Record 25 of Set 28 | garowe
# Processing Record 26 of Set 28 | ayagoz
# Processing Record 27 of Set 28 | karpogory
# Processing Record 28 of Set 28 | hofn
# Processing Record 29 of Set 28 | soanierana ivongo
# Processing Record 30 of Set 28 | itainopolis
# Processing Record 31 of Set 28 | torri di quartesolo
# Processing Record 32 of Set 28 | saint-francois
# Processing Record 33 of Set 28 | cootehill
# Processing Record 34 of Set 28 | ashqelon
# Processing Record 35 of Set 28 | nambiyur
# Processing Record 36 of Set 28 | lodja
# Processing Record 37 of Set 28 | asyut
# Processing Record 38 of Set 28 | keti bandar
# Processing Record 39 of Set 28 | kathmandu
# Processing Record 40 of Set 28 | nioro
# Processing Record 41 of Set 28 | high rock
# Processing Record 42 of Set 28 | tonekabon
# Processing Record 43 of Set 28 | ilave
# Processing Record 44 of Set 28 | rawah
# Processing Record 45 of Set 28 | rolim de moura
# City not found. Skipping...
# Processing Record 46 of Set 28 | zavolzhsk
# Processing Record 47 of Set 28 | verkhnyaya inta
# Processing Record 48 of Set 28 | ingenbohl
# Processing Record 49 of Set 28 | brora
# Processing Record 50 of Set 28 | khor
# Processing Record 1 of Set 29 | la libertad
# Processing Record 2 of Set 29 | wattegama
# Processing Record 3 of Set 29 | kurkino
# Processing Record 4 of Set 29 | minab
# Processing Record 5 of Set 29 | dhidhdhoo
# Processing Record 6 of Set 29 | cumana
# Processing Record 7 of Set 29 | makueni
# Processing Record 8 of Set 29 | uzventis
# Processing Record 9 of Set 29 | tete
# Processing Record 10 of Set 29 | mundi
# Processing Record 11 of Set 29 | qandala
# Processing Record 12 of Set 29 | strezhevoy
# Processing Record 13 of Set 29 | ouargaye
# Processing Record 14 of Set 29 | lukovetskiy
# Processing Record 15 of Set 29 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 29 | ramhormoz
# Processing Record 17 of Set 29 | rosetta
# Processing Record 18 of Set 29 | qurbus
# Processing Record 19 of Set 29 | andros town
# Processing Record 20 of Set 29 | soledade
# Processing Record 21 of Set 29 | tervel
# Processing Record 22 of Set 29 | mikhaylovka
# Processing Record 23 of Set 29 | cabedelo
# Processing Record 24 of Set 29 | bonoua
# Processing Record 25 of Set 29 | alice town
# Processing Record 26 of Set 29 | bahia honda
# Processing Record 27 of Set 29 | svolvaer
# Processing Record 28 of Set 29 | mwene-ditu
# Processing Record 29 of Set 29 | druzhba
# Processing Record 30 of Set 29 | necochea
# Processing Record 31 of Set 29 | ogulin
# Processing Record 32 of Set 29 | atasu
# Processing Record 33 of Set 29 | oil city
# Processing Record 34 of Set 29 | mokshan
# Processing Record 35 of Set 29 | guatire
# Processing Record 36 of Set 29 | ivanteyevka
# Processing Record 37 of Set 29 | ibicarai
# Processing Record 38 of Set 29 | barra
# Processing Record 39 of Set 29 | felipe carrillo puerto
# Processing Record 40 of Set 29 | kuloy
# Processing Record 41 of Set 29 | monte cristi
# City not found. Skipping...
# Processing Record 42 of Set 29 | cheuskiny
# City not found. Skipping...
# Processing Record 43 of Set 29 | longlac
# City not found. Skipping...
# Processing Record 44 of Set 29 | chernogolovka
# Processing Record 45 of Set 29 | eskil
# Processing Record 46 of Set 29 | cururupu
# Processing Record 47 of Set 29 | butembo
# Processing Record 48 of Set 29 | hammerfest
# Processing Record 49 of Set 29 | miranda de ebro
# Processing Record 50 of Set 29 | voka
# Processing Record 1 of Set 30 | asuncion
# Processing Record 2 of Set 30 | surt
# Processing Record 3 of Set 30 | malwan
# City not found. Skipping...
# Processing Record 4 of Set 30 | olafsvik
# Processing Record 5 of Set 30 | linhares
# Processing Record 6 of Set 30 | ambilobe
# Processing Record 7 of Set 30 | cordoba
# Processing Record 8 of Set 30 | bar-le-duc
# Processing Record 9 of Set 30 | tibati
# Processing Record 10 of Set 30 | xai-xai
# Processing Record 11 of Set 30 | celje
# Processing Record 12 of Set 30 | lesnyye polyany
# Processing Record 13 of Set 30 | bedele
# Processing Record 14 of Set 30 | colares
# Processing Record 15 of Set 30 | kudahuvadhoo
# Processing Record 16 of Set 30 | bingol
# Processing Record 17 of Set 30 | benghazi
# Processing Record 18 of Set 30 | somerset east
# Processing Record 19 of Set 30 | villa carlos paz
# Processing Record 20 of Set 30 | tucurui
# Processing Record 21 of Set 30 | laurel
# Processing Record 22 of Set 30 | romulus
# Processing Record 23 of Set 30 | kamina
# Processing Record 24 of Set 30 | zhezkazgan
# Processing Record 25 of Set 30 | maxixe
# Processing Record 26 of Set 30 | uige
# Processing Record 27 of Set 30 | kimamba
# Processing Record 28 of Set 30 | tabou
# Processing Record 29 of Set 30 | novyy urengoy
# Processing Record 30 of Set 30 | sisimiut
# Processing Record 31 of Set 30 | raahe
# Processing Record 32 of Set 30 | asfi
# Processing Record 33 of Set 30 | ghanzi
# Processing Record 34 of Set 30 | port shepstone
# Processing Record 35 of Set 30 | muyezerskiy
# Processing Record 36 of Set 30 | sao joao do piaui
# Processing Record 37 of Set 30 | petropavlovka
# Processing Record 38 of Set 30 | karakendzha
# City not found. Skipping...
# Processing Record 39 of Set 30 | general roca
# Processing Record 40 of Set 30 | yanaul
# Processing Record 41 of Set 30 | mwadui
# Processing Record 42 of Set 30 | tabulbah
# City not found. Skipping...
# Processing Record 43 of Set 30 | nioki
# Processing Record 44 of Set 30 | baghdad
# Processing Record 45 of Set 30 | mrirt
# City not found. Skipping...
# Processing Record 46 of Set 30 | kaabong
# Processing Record 47 of Set 30 | diego de almagro
# Processing Record 48 of Set 30 | san alberto
# Processing Record 49 of Set 30 | vieques
# Processing Record 50 of Set 30 | brae
# Processing Record 1 of Set 31 | jumla
# Processing Record 2 of Set 31 | mount pleasant
# Processing Record 3 of Set 31 | springbok
# Processing Record 4 of Set 31 | akureyri
# Processing Record 5 of Set 31 | glazov
# Processing Record 6 of Set 31 | ouro preto do oeste
# Processing Record 7 of Set 31 | usinsk
# Processing Record 8 of Set 31 | ndele
# Processing Record 9 of Set 31 | paramonga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df= pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   East London      ZA -33.0153   27.9116     67.93        81          93
# 1     Busselton      AU -33.6500  115.3333     53.01        96         100
# 2       Ushuaia      AR -54.8000  -68.3000     50.00        53           0
# 3  Punta Arenas      CL -53.1500  -70.9167     46.40        66           0
# 4    Sergeyevka      KZ  53.8800   67.4158     40.17        71          49
# 5   Clyde River      CA  70.4692  -68.5914     12.20        92          75
# 6     Ilulissat      GL  69.2167  -51.1000     26.60        54           6
# 7     Bharatpur      IN  27.2167   77.4833     76.60        35           3
# 8      Hermanus      ZA -34.4187   19.2345     64.00        84          19
# 9    Bredasdorp      ZA -34.5322   20.0403     60.80        94          97
#
#    Wind Speed Current Description
# 0        2.51     overcast clouds
# 1        9.35     overcast clouds
# 2        0.51           clear sky
# 3        9.22           clear sky
# 4        5.30    scattered clouds
# 5       26.46                snow
# 6        8.05           clear sky
# 7        5.93           clear sky
# 8        4.00          few clouds
# 9        9.22     overcast clouds

# %%
# Create the output file (CSV)
output_data_file= 'Weather_Database/WeatherPy_Database.csv'
# Export the City_data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
